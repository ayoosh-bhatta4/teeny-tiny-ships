# %% [markdown]
# <a href="https://colab.research.google.com/github/ayoosh-bhatta4/teeny-tiny-ships/blob/main/organizer/organizer_custom.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
